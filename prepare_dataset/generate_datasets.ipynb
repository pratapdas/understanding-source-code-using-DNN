# %%
import os, sys, time, json, sqlite3, re, random, numpy as np, pickle as cp, glob, operator
from copy import deepcopy
from collections import OrderedDict
import subprocess32 as subprocess
from functools import partial
np.random.seed(1307)
sys.path.append('..')
from pycparser import parse_file, c_ast
from pycparser.plyparser import ParseError

from util.helpers import get_rev_dict, remove_non_ascii, make_dir_if_not_exists as mkdir
from util.helpers import get_curr_time_string, remove_non_ascii
from util.helpers import isolate_line, fetch_line, extract_line_number, get_lines, recompose_program
from util.ast_helpers import get_subtree_list, get_linearized_ast, get_ast
from concurrent.futures import ThreadPoolExecutor
from pprint import pprint
#from util.c_tokenizer import C_Tokenizer
#tokenize = C_Tokenizer().tokenize
# Out:
# Using TensorFlow backend.

# %%
dataset = '../data/dataset.db'
with sqlite3.connect(dataset) as conn:
    c = conn.cursor()

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(c.fetchall())
# Out:
# [('test_runs',), ('orgsource',), ('test_run_summary',), ('programs',), ('problems',)]

# %%
destination = '../data/network_inputs/bugloc-%s/' % time.strftime("%d-%m")
mkdir(destination)
print(destination)
# Out:
# ../data/network_inputs/bugloc-17-09/

# %%
eval_set = np.load('../data/eval_set.npy', allow_pickle=True).item()
eval_dict = {}
for problem_id in eval_set:
    for program_id, row in eval_set[problem_id].items():
        eval_dict[program_id] = row

eval_set_program_ids = set(eval_dict.keys())
print ('len(eval_set_program_ids):', len(eval_set_program_ids))
# Out:
# len(eval_set_program_ids): 2167

# %%
query='''SELECT p.program_id, subtree_list_ast_without_leaves, test_id, t.verdict FROM 
        programs p INNER JOIN orgsource o ON o.program_id = p.program_id
        INNER JOIN problems q ON o.problem_id = q.problem_id 
        INNER JOIN test_runs t ON t.program_id = p.program_id
        INNER JOIN test_run_summary trs ON trs.program_id = p.program_id
        WHERE trs.verdict<>"ALL_FAIL" AND q.problem_id=?;'''

problem_ids = [str(row[0]) for row in c.execute('SELECT DISTINCT problem_id FROM orgsource;')]
print('len(problem_ids)', len(problem_ids), problem_ids[0])
# Out:
# len(problem_ids) 29 3024

# %%
max_programs_per_test_case_result = 700

test_wise_counts = {}
eval_test_wise_counts = {}
all_data = {}
all_eval_data = {}
test_id_to_problem_id_map = {}

with sqlite3.connect(dataset) as conn:
    c = conn.cursor()

for problem_id in problem_ids:
        test_wise_counts[problem_id] = {}
        eval_test_wise_counts[problem_id] = {}
        this_data_len = 0
        this_eval_data = []
        all_data[problem_id] = {}
        for row in c.execute(query, (problem_id,)):
            program_id = row[0]
            subtree_list_ast = json.loads(row[1])
            test_id = str(row[2])
            verdict = row[3]
            
            if test_id in test_id_to_problem_id_map:
                assert test_id_to_problem_id_map[test_id] == problem_id
            test_id_to_problem_id_map[test_id] = problem_id
            
            if test_id not in test_wise_counts[problem_id]:
                test_wise_counts[problem_id][test_id] = {0:[], 1:[]}
                eval_test_wise_counts[problem_id][test_id] = {0:[], 1:[]}
                all_data[problem_id][test_id] = {0:[], 1:[]}

            if program_id in eval_set_program_ids:
                this_eval_data += [(program_id, subtree_list_ast, test_id, verdict)]
                eval_test_wise_counts[problem_id][test_id][verdict] += [program_id]
            elif len(test_wise_counts[problem_id][test_id][verdict]) < max_programs_per_test_case_result:
                all_data[problem_id][test_id][verdict] += [(program_id, subtree_list_ast, test_id, verdict)]
                test_wise_counts[problem_id][test_id][verdict] += [program_id]
                this_data_len += 1
                
        all_eval_data[problem_id] = this_eval_data
        print('problem_id: %6s' % problem_id, '#examples:', this_data_len, '#eval_examples:', len(this_eval_data))

total = 0
for problem_id in all_data:
    for test_id in all_data[problem_id]:
        for verdict in all_data[problem_id][test_id]:
            total += len(all_data[problem_id][test_id][verdict])
print('total', total)

c.close()
conn.close()
# Out:
# problem_id:   3024 #examples: 7658 #eval_examples: 1848
# problem_id:   3035 #examples: 10138 #eval_examples: 730
# problem_id:   3018 #examples: 7983 #eval_examples: 828
# problem_id:   3003 #examples: 9602 #eval_examples: 104
# problem_id:   3026 #examples: 5136 #eval_examples: 390
# problem_id:   3019 #examples: 4590 #eval_examples: 516
# problem_id:   3032 #examples: 6569 #eval_examples: 357
# problem_id:   3002 #examples: 6409 #eval_examples: 490
# problem_id:   3008 #examples: 10155 #eval_examples: 927
# problem_id:   3043 #examples: 8475 #eval_examples: 972
# problem_id:   3016 #examples: 9536 #eval_examples: 510
# problem_id:   3037 #examples: 4752 #eval_examples: 801
# problem_id:   3047 #examples: 7460 #eval_examples: 280
# problem_id:   3007 #examples: 3930 #eval_examples: 390
# problem_id:   3009 #examples: 6589 #eval_examples: 609
# problem_id:   3049 #examples: 11763 #eval_examples: 2790
# problem_id:   3030 #examples: 7830 #eval_examples: 90
# problem_id:   3055 #examples: 12387 #eval_examples: 1170
# problem_id:   3033 #examples: 7163 #eval_examples: 552
# problem_id:   3054 #examples: 7744 #eval_examples: 456
# problem_id:   3044 #examples: 4361 #eval_examples: 168
# problem_id:   3050 #examples: 5488 #eval_examples: 420
# problem_id:   3010 #examples: 5013 #eval_examples: 441
# problem_id:   3025 #examples: 5327 #eval_examples: 336
# problem_id:   3013 #examples: 7193 #eval_examples: 175
# problem_id:   3036 #examples: 5590 #eval_examples: 390
# problem_id:   3017 #examples: 6670 #eval_examples: 190
# problem_id:   3048 #examples: 5008 #eval_examples: 80
# problem_id:   3029 #examples: 7730 #eval_examples: 310
# total 208249

# %%
for problem_id in all_data:
    print ('problem_id:', problem_id)
    for test_id in test_wise_counts[problem_id]:
        print (test_id.replace('.txt', '').replace('IN_', ''), 
        'fail:', len(test_wise_counts[problem_id][test_id][0]),
        'pass:', len(test_wise_counts[problem_id][test_id][1]))
# Out:
# problem_id: 3024
# 40013 fail: 273 pass: 700
# 40024 fail: 553 pass: 455
# 40078 fail: 250 pass: 700
# 40224 fail: 273 pass: 700
# 40297 fail: 546 pass: 462
# 40331 fail: 248 pass: 700
# 40394 fail: 199 pass: 700
# 40410 fail: 199 pass: 700
# problem_id: 3035
# 40021 fail: 527 pass: 529
# 40082 fail: 392 pass: 664
# 40139 fail: 390 pass: 666
# 40205 fail: 382 pass: 674
# 40212 fail: 393 pass: 663
# 40237 fail: 394 pass: 662
# 40294 fail: 248 pass: 700
# 40312 fail: 224 pass: 700
# 40352 fail: 265 pass: 700
# 40383 fail: 265 pass: 700
# problem_id: 3018
# 40049 fail: 431 pass: 456
# 40108 fail: 312 pass: 575
# 40274 fail: 360 pass: 527
# 40334 fail: 308 pass: 579
# 40335 fail: 313 pass: 574
# 40426 fail: 311 pass: 576
# 40444 fail: 332 pass: 555
# 40447 fail: 342 pass: 545
# 40449 fail: 459 pass: 428
# problem_id: 3003
# 40006 fail: 700 pass: 531
# 40015 fail: 700 pass: 279
# 40141 fail: 231 pass: 700
# 40156 fail: 391 pass: 700
# 40362 fail: 686 pass: 700
# 40409 fail: 700 pass: 693
# 40453 fail: 700 pass: 491
# 40460 fail: 700 pass: 700
# problem_id: 3026
# 40002 fail: 243 pass: 613
# 40134 fail: 193 pass: 663
# 40218 fail: 238 pass: 618
# 40344 fail: 317 pass: 539
# 40392 fail: 433 pass: 423
# 40401 fail: 243 pass: 613
# problem_id: 3019
# 40009 fail: 400 pass: 365
# 40063 fail: 120 pass: 645
# 40100 fail: 301 pass: 464
# 40159 fail: 292 pass: 473
# 40188 fail: 123 pass: 642
# 40433 fail: 226 pass: 539
# problem_id: 3032
# 40118 fail: 562 pass: 407
# 40138 fail: 111 pass: 700
# 40178 fail: 267 pass: 700
# 40179 fail: 314 pass: 655
# 40198 fail: 580 pass: 389
# 40303 fail: 285 pass: 684
# 40403 fail: 215 pass: 700
# problem_id: 3002
# 40117 fail: 225 pass: 700
# 40137 fail: 165 pass: 700
# 40151 fail: 165 pass: 700
# 40202 fail: 205 pass: 700
# 40215 fail: 163 pass: 700
# 40413 fail: 310 pass: 683
# 40415 fail: 293 pass: 700
# problem_id: 3008
# 40032 fail: 328 pass: 700
# 40042 fail: 422 pass: 700
# 40062 fail: 259 pass: 700
# 40166 fail: 327 pass: 700
# 40220 fail: 592 pass: 637
# 40229 fail: 403 pass: 700
# 40332 fail: 602 pass: 627
# 40343 fail: 603 pass: 626
# 40459 fail: 602 pass: 627
# problem_id: 3043
# 40048 fail: 418 pass: 535
# 40072 fail: 340 pass: 613
# 40095 fail: 252 pass: 700
# 40203 fail: 238 pass: 700
# 40206 fail: 297 pass: 656
# 40207 fail: 387 pass: 566
# 40209 fail: 306 pass: 647
# 40248 fail: 167 pass: 700
# 40293 fail: 262 pass: 691
# problem_id: 3016
# 40069 fail: 305 pass: 675
# 40175 fail: 700 pass: 211
# 40246 fail: 479 pass: 501
# 40265 fail: 541 pass: 439
# 40281 fail: 305 pass: 675
# 40313 fail: 700 pass: 215
# 40336 fail: 483 pass: 497
# 40356 fail: 700 pass: 223
# 40363 fail: 545 pass: 435
# 40424 fail: 700 pass: 207
# problem_id: 3037
# 40086 fail: 260 pass: 268
# 40097 fail: 234 pass: 294
# 40165 fail: 206 pass: 322
# 40225 fail: 190 pass: 338
# 40243 fail: 223 pass: 305
# 40361 fail: 212 pass: 316
# 40381 fail: 277 pass: 251
# 40411 fail: 229 pass: 299
# 40448 fail: 153 pass: 375
# problem_id: 3047
# 40018 fail: 536 pass: 575
# 40023 fail: 541 pass: 570
# 40038 fail: 528 pass: 583
# 40093 fail: 544 pass: 567
# 40269 fail: 425 pass: 686
# 40348 fail: 412 pass: 699
# 40451 fail: 94 pass: 700
# problem_id: 3007
# 40011 fail: 379 pass: 407
# 40083 fail: 197 pass: 589
# 40099 fail: 222 pass: 564
# 40107 fail: 385 pass: 401
# 40270 fail: 301 pass: 485
# problem_id: 3009
# 40064 fail: 406 pass: 554
# 40081 fail: 439 pass: 521
# 40087 fail: 528 pass: 432
# 40088 fail: 129 pass: 700
# 40131 fail: 387 pass: 573
# 40221 fail: 486 pass: 474
# 40329 fail: 473 pass: 487
# problem_id: 3049
# 40109 fail: 700 pass: 700
# 40133 fail: 385 pass: 700
# 40155 fail: 700 pass: 700
# 40189 fail: 392 pass: 700
# 40191 fail: 700 pass: 700
# 40239 fail: 700 pass: 700
# 40251 fail: 700 pass: 700
# 40314 fail: 700 pass: 700
# 40388 fail: 486 pass: 700
# problem_id: 3030
# 40025 fail: 297 pass: 573
# 40122 fail: 533 pass: 337
# 40226 fail: 504 pass: 366
# 40236 fail: 486 pass: 384
# 40340 fail: 175 pass: 695
# 40396 fail: 439 pass: 431
# 40398 fail: 385 pass: 485
# 40404 fail: 505 pass: 365
# 40416 fail: 394 pass: 476
# problem_id: 3055
# 40051 fail: 700 pass: 700
# 40112 fail: 641 pass: 700
# 40142 fail: 700 pass: 700
# 40157 fail: 700 pass: 700
# 40259 fail: 700 pass: 700
# 40261 fail: 641 pass: 700
# 40341 fail: 700 pass: 700
# 40389 fail: 605 pass: 700
# 40439 fail: 700 pass: 700
# problem_id: 3033
# 40008 fail: 114 pass: 700
# 40036 fail: 481 pass: 426
# 40094 fail: 418 pass: 489
# 40301 fail: 539 pass: 368
# 40315 fail: 402 pass: 505
# 40353 fail: 320 pass: 587
# 40367 fail: 555 pass: 352
# 40399 fail: 372 pass: 535
# problem_id: 3054
# 40128 fail: 646 pass: 352
# 40260 fail: 585 pass: 413
# 40272 fail: 212 pass: 700
# 40342 fail: 235 pass: 700
# 40360 fail: 207 pass: 700
# 40365 fail: 670 pass: 328
# 40402 fail: 638 pass: 360
# 40441 fail: 324 pass: 674
# problem_id: 3044
# 40120 fail: 289 pass: 334
# 40127 fail: 161 pass: 462
# 40180 fail: 152 pass: 471
# 40196 fail: 299 pass: 324
# 40318 fail: 156 pass: 467
# 40350 fail: 172 pass: 451
# 40364 fail: 322 pass: 301
# problem_id: 3050
# 40045 fail: 449 pass: 335
# 40173 fail: 93 pass: 691
# 40197 fail: 428 pass: 356
# 40217 fail: 474 pass: 310
# 40268 fail: 198 pass: 586
# 40275 fail: 492 pass: 292
# 40291 fail: 443 pass: 341
# problem_id: 3010
# 40017 fail: 72 pass: 485
# 40020 fail: 232 pass: 325
# 40046 fail: 342 pass: 215
# 40091 fail: 401 pass: 156
# 40111 fail: 395 pass: 162
# 40227 fail: 257 pass: 300
# 40238 fail: 230 pass: 327
# 40242 fail: 417 pass: 140
# 40289 fail: 131 pass: 426
# problem_id: 3025
# 40092 fail: 453 pass: 314
# 40110 fail: 199 pass: 568
# 40113 fail: 391 pass: 376
# 40144 fail: 461 pass: 306
# 40256 fail: 489 pass: 278
# 40358 fail: 449 pass: 318
# 40371 fail: 25 pass: 700
# problem_id: 3013
# 40074 fail: 453 pass: 587
# 40160 fail: 634 pass: 406
# 40230 fail: 404 pass: 636
# 40250 fail: 618 pass: 422
# 40276 fail: 345 pass: 695
# 40333 fail: 321 pass: 700
# 40418 fail: 272 pass: 700
# problem_id: 3036
# 40106 fail: 285 pass: 664
# 40194 fail: 307 pass: 642
# 40283 fail: 476 pass: 473
# 40327 fail: 453 pass: 496
# 40397 fail: 297 pass: 652
# 40456 fail: 145 pass: 700
# problem_id: 3017
# 40071 fail: 409 pass: 258
# 40171 fail: 392 pass: 275
# 40181 fail: 387 pass: 280
# 40185 fail: 114 pass: 553
# 40223 fail: 360 pass: 307
# 40298 fail: 462 pass: 205
# 40305 fail: 362 pass: 305
# 40306 fail: 433 pass: 234
# 40369 fail: 353 pass: 314
# 40390 fail: 286 pass: 381
# problem_id: 3048
# 40031 fail: 318 pass: 308
# 40039 fail: 435 pass: 191
# 40164 fail: 287 pass: 339
# 40290 fail: 403 pass: 223
# 40299 fail: 111 pass: 515
# 40310 fail: 275 pass: 351
# 40349 fail: 427 pass: 199
# 40442 fail: 285 pass: 341
# problem_id: 3029
# 40061 fail: 382 pass: 391
# 40177 fail: 382 pass: 391
# 40193 fail: 405 pass: 368
# 40211 fail: 74 pass: 699
# 40264 fail: 381 pass: 392
# 40295 fail: 370 pass: 403
# 40316 fail: 124 pass: 649
# 40326 fail: 378 pass: 395
# 40386 fail: 431 pass: 342
# 40408 fail: 123 pass: 650

# %%
for problem_id in all_eval_data:
    print ('problem_id:', problem_id)
    for test_id in eval_test_wise_counts[problem_id]:
        print (test_id.replace('.txt', '').replace('IN_', ''), 'fail:', 
               len(eval_test_wise_counts[problem_id][test_id][0]),'pass:', 
               len(eval_test_wise_counts[problem_id][test_id][1]))
# Out:
# problem_id: 3024
# 40013 fail: 36 pass: 195
# 40024 fail: 202 pass: 29
# 40078 fail: 30 pass: 201
# 40224 fail: 36 pass: 195
# 40297 fail: 197 pass: 34
# 40331 fail: 30 pass: 201
# 40394 fail: 27 pass: 204
# 40410 fail: 27 pass: 204
# problem_id: 3035
# 40021 fail: 28 pass: 45
# 40082 fail: 26 pass: 47
# 40139 fail: 28 pass: 45
# 40205 fail: 27 pass: 46
# 40212 fail: 33 pass: 40
# 40237 fail: 33 pass: 40
# 40294 fail: 13 pass: 60
# 40312 fail: 11 pass: 62
# 40352 fail: 9 pass: 64
# 40383 fail: 9 pass: 64
# problem_id: 3018
# 40049 fail: 63 pass: 29
# 40108 fail: 9 pass: 83
# 40274 fail: 28 pass: 64
# 40334 fail: 24 pass: 68
# 40335 fail: 8 pass: 84
# 40426 fail: 24 pass: 68
# 40444 fail: 10 pass: 82
# 40447 fail: 21 pass: 71
# 40449 fail: 63 pass: 29
# problem_id: 3003
# 40006 fail: 3 pass: 10
# 40015 fail: 7 pass: 6
# 40141 fail: 1 pass: 12
# 40156 fail: 3 pass: 10
# 40362 fail: 1 pass: 12
# 40409 fail: 2 pass: 11
# 40453 fail: 7 pass: 6
# 40460 fail: 1 pass: 12
# problem_id: 3026
# 40002 fail: 12 pass: 53
# 40134 fail: 27 pass: 38
# 40218 fail: 16 pass: 49
# 40344 fail: 21 pass: 44
# 40392 fail: 15 pass: 50
# 40401 fail: 13 pass: 52
# problem_id: 3019
# 40009 fail: 50 pass: 36
# 40063 fail: 27 pass: 59
# 40100 fail: 45 pass: 41
# 40159 fail: 37 pass: 49
# 40188 fail: 22 pass: 64
# 40433 fail: 25 pass: 61
# problem_id: 3032
# 40118 fail: 42 pass: 9
# 40138 fail: 6 pass: 45
# 40178 fail: 17 pass: 34
# 40179 fail: 21 pass: 30
# 40198 fail: 43 pass: 8
# 40303 fail: 24 pass: 27
# 40403 fail: 4 pass: 47
# problem_id: 3002
# 40117 fail: 31 pass: 39
# 40137 fail: 26 pass: 44
# 40151 fail: 26 pass: 44
# 40202 fail: 27 pass: 43
# 40215 fail: 20 pass: 50
# 40413 fail: 47 pass: 23
# 40415 fail: 40 pass: 30
# problem_id: 3008
# 40032 fail: 31 pass: 72
# 40042 fail: 58 pass: 45
# 40062 fail: 35 pass: 68
# 40166 fail: 31 pass: 72
# 40220 fail: 73 pass: 30
# 40229 fail: 54 pass: 49
# 40332 fail: 73 pass: 30
# 40343 fail: 74 pass: 29
# 40459 fail: 74 pass: 29
# problem_id: 3043
# 40048 fail: 94 pass: 14
# 40072 fail: 37 pass: 71
# 40095 fail: 28 pass: 80
# 40203 fail: 26 pass: 82
# 40206 fail: 38 pass: 70
# 40207 fail: 92 pass: 16
# 40209 fail: 35 pass: 73
# 40248 fail: 19 pass: 89
# 40293 fail: 31 pass: 77
# problem_id: 3016
# 40069 fail: 20 pass: 31
# 40175 fail: 33 pass: 18
# 40246 fail: 19 pass: 32
# 40265 fail: 24 pass: 27
# 40281 fail: 20 pass: 31
# 40313 fail: 33 pass: 18
# 40336 fail: 19 pass: 32
# 40356 fail: 32 pass: 19
# 40363 fail: 25 pass: 26
# 40424 fail: 32 pass: 19
# problem_id: 3037
# 40086 fail: 67 pass: 22
# 40097 fail: 24 pass: 65
# 40165 fail: 30 pass: 59
# 40225 fail: 26 pass: 63
# 40243 fail: 23 pass: 66
# 40361 fail: 30 pass: 59
# 40381 fail: 69 pass: 20
# 40411 fail: 24 pass: 65
# 40448 fail: 18 pass: 71
# problem_id: 3047
# 40018 fail: 28 pass: 12
# 40023 fail: 29 pass: 11
# 40038 fail: 28 pass: 12
# 40093 fail: 20 pass: 20
# 40269 fail: 18 pass: 22
# 40348 fail: 20 pass: 20
# 40451 fail: 2 pass: 38
# problem_id: 3007
# 40011 fail: 42 pass: 36
# 40083 fail: 16 pass: 62
# 40099 fail: 12 pass: 66
# 40107 fail: 41 pass: 37
# 40270 fail: 23 pass: 55
# problem_id: 3009
# 40064 fail: 47 pass: 40
# 40081 fail: 54 pass: 33
# 40087 fail: 69 pass: 18
# 40088 fail: 13 pass: 74
# 40131 fail: 45 pass: 42
# 40221 fail: 48 pass: 39
# 40329 fail: 49 pass: 38
# problem_id: 3049
# 40109 fail: 225 pass: 85
# 40133 fail: 125 pass: 185
# 40155 fail: 117 pass: 193
# 40189 fail: 125 pass: 185
# 40191 fail: 122 pass: 188
# 40239 fail: 223 pass: 87
# 40251 fail: 225 pass: 85
# 40314 fail: 224 pass: 86
# 40388 fail: 152 pass: 158
# problem_id: 3030
# 40025 fail: 4 pass: 6
# 40122 fail: 7 pass: 3
# 40226 fail: 4 pass: 6
# 40236 fail: 5 pass: 5
# 40340 fail: 3 pass: 7
# 40396 fail: 6 pass: 4
# 40398 fail: 5 pass: 5
# 40404 fail: 4 pass: 6
# 40416 fail: 5 pass: 5
# problem_id: 3055
# 40051 fail: 46 pass: 84
# 40112 fail: 20 pass: 110
# 40142 fail: 94 pass: 36
# 40157 fail: 44 pass: 86
# 40259 fail: 30 pass: 100
# 40261 fail: 28 pass: 102
# 40341 fail: 37 pass: 93
# 40389 fail: 20 pass: 110
# 40439 fail: 36 pass: 94
# problem_id: 3033
# 40008 fail: 3 pass: 66
# 40036 fail: 42 pass: 27
# 40094 fail: 30 pass: 39
# 40301 fail: 51 pass: 18
# 40315 fail: 31 pass: 38
# 40353 fail: 21 pass: 48
# 40367 fail: 53 pass: 16
# 40399 fail: 28 pass: 41
# problem_id: 3054
# 40128 fail: 53 pass: 4
# 40260 fail: 53 pass: 4
# 40272 fail: 6 pass: 51
# 40342 fail: 4 pass: 53
# 40360 fail: 6 pass: 51
# 40365 fail: 54 pass: 3
# 40402 fail: 54 pass: 3
# 40441 fail: 17 pass: 40
# problem_id: 3044
# 40120 fail: 9 pass: 15
# 40127 fail: 1 pass: 23
# 40180 fail: 4 pass: 20
# 40196 fail: 13 pass: 11
# 40318 fail: 3 pass: 21
# 40350 fail: 6 pass: 18
# 40364 fail: 11 pass: 13
# problem_id: 3050
# 40045 fail: 45 pass: 15
# 40173 fail: 14 pass: 46
# 40197 fail: 42 pass: 18
# 40217 fail: 42 pass: 18
# 40268 fail: 17 pass: 43
# 40275 fail: 40 pass: 20
# 40291 fail: 47 pass: 13
# problem_id: 3010
# 40017 fail: 3 pass: 46
# 40020 fail: 14 pass: 35
# 40046 fail: 34 pass: 15
# 40091 fail: 34 pass: 15
# 40111 fail: 43 pass: 6
# 40227 fail: 32 pass: 17
# 40238 fail: 14 pass: 35
# 40242 fail: 39 pass: 10
# 40289 fail: 3 pass: 46
# problem_id: 3025
# 40092 fail: 43 pass: 5
# 40110 fail: 28 pass: 20
# 40113 fail: 34 pass: 14
# 40144 fail: 40 pass: 8
# 40256 fail: 48 pass: 0
# 40358 fail: 42 pass: 6
# 40371 fail: 5 pass: 43
# problem_id: 3013
# 40074 fail: 17 pass: 8
# 40160 fail: 18 pass: 7
# 40230 fail: 5 pass: 20
# 40250 fail: 17 pass: 8
# 40276 fail: 4 pass: 21
# 40333 fail: 7 pass: 18
# 40418 fail: 2 pass: 23
# problem_id: 3036
# 40106 fail: 18 pass: 47
# 40194 fail: 21 pass: 44
# 40283 fail: 38 pass: 27
# 40327 fail: 39 pass: 26
# 40397 fail: 22 pass: 43
# 40456 fail: 17 pass: 48
# problem_id: 3017
# 40071 fail: 14 pass: 5
# 40171 fail: 11 pass: 8
# 40181 fail: 14 pass: 5
# 40185 fail: 0 pass: 19
# 40223 fail: 12 pass: 7
# 40298 fail: 19 pass: 0
# 40305 fail: 13 pass: 6
# 40306 fail: 19 pass: 0
# 40369 fail: 11 pass: 8
# 40390 fail: 12 pass: 7
# problem_id: 3048
# 40031 fail: 8 pass: 2
# 40039 fail: 9 pass: 1
# 40164 fail: 8 pass: 2
# 40290 fail: 6 pass: 4
# 40299 fail: 2 pass: 8
# 40310 fail: 4 pass: 6
# 40349 fail: 9 pass: 1
# 40442 fail: 4 pass: 6
# problem_id: 3029
# 40061 fail: 14 pass: 17
# 40177 fail: 14 pass: 17
# 40193 fail: 16 pass: 15
# 40211 fail: 5 pass: 26
# 40264 fail: 17 pass: 14
# 40295 fail: 16 pass: 15
# 40316 fail: 6 pass: 25
# 40326 fail: 16 pass: 15
# 40386 fail: 20 pass: 11
# 40408 fail: 6 pass: 25

# %% [markdown]
# ## Upsample data for balancing

# %%
for problem_id in all_data:
    for test_id in all_data[problem_id]:
        if len(all_data[problem_id][test_id][0]) < len(all_data[problem_id][test_id][1]):
            small, target_len = all_data[problem_id][test_id][0], len(all_data[problem_id][test_id][1])
        elif len(all_data[problem_id][test_id][0]) > len(all_data[problem_id][test_id][1]):
            small, target_len = all_data[problem_id][test_id][1], len(all_data[problem_id][test_id][0])
        else:
            continue
        np.random.seed(int(test_id.replace('.txt', '').replace('IN_', '')))
        upsamples = np.random.choice(len(small), target_len-len(small))
        for idx in upsamples:
            small.append(small[idx])
        assert len(all_data[problem_id][test_id][0]) == len(all_data[problem_id][test_id][1])

# %%
np.random.seed(1307)

# %%
for problem_id in all_data:
    print('problem_id:', problem_id)
    for test_id in all_data[problem_id]:
        print (test_id.replace('.txt', '').replace('IN_', ''), 
               'fail:', len(all_data[problem_id][test_id][0]), 
               'pass:', len(all_data[problem_id][test_id][1]))
        assert len(all_data[problem_id][test_id][0]) == len(all_data[problem_id][test_id][1])
# Out:
# problem_id: 3024
# 40013 fail: 700 pass: 700
# 40024 fail: 553 pass: 553
# 40078 fail: 700 pass: 700
# 40224 fail: 700 pass: 700
# 40297 fail: 546 pass: 546
# 40331 fail: 700 pass: 700
# 40394 fail: 700 pass: 700
# 40410 fail: 700 pass: 700
# problem_id: 3035
# 40021 fail: 529 pass: 529
# 40082 fail: 664 pass: 664
# 40139 fail: 666 pass: 666
# 40205 fail: 674 pass: 674
# 40212 fail: 663 pass: 663
# 40237 fail: 662 pass: 662
# 40294 fail: 700 pass: 700
# 40312 fail: 700 pass: 700
# 40352 fail: 700 pass: 700
# 40383 fail: 700 pass: 700
# problem_id: 3018
# 40049 fail: 456 pass: 456
# 40108 fail: 575 pass: 575
# 40274 fail: 527 pass: 527
# 40334 fail: 579 pass: 579
# 40335 fail: 574 pass: 574
# 40426 fail: 576 pass: 576
# 40444 fail: 555 pass: 555
# 40447 fail: 545 pass: 545
# 40449 fail: 459 pass: 459
# problem_id: 3003
# 40006 fail: 700 pass: 700
# 40015 fail: 700 pass: 700
# 40141 fail: 700 pass: 700
# 40156 fail: 700 pass: 700
# 40362 fail: 700 pass: 700
# 40409 fail: 700 pass: 700
# 40453 fail: 700 pass: 700
# 40460 fail: 700 pass: 700
# problem_id: 3026
# 40002 fail: 613 pass: 613
# 40134 fail: 663 pass: 663
# 40218 fail: 618 pass: 618
# 40344 fail: 539 pass: 539
# 40392 fail: 433 pass: 433
# 40401 fail: 613 pass: 613
# problem_id: 3019
# 40009 fail: 400 pass: 400
# 40063 fail: 645 pass: 645
# 40100 fail: 464 pass: 464
# 40159 fail: 473 pass: 473
# 40188 fail: 642 pass: 642
# 40433 fail: 539 pass: 539
# problem_id: 3032
# 40118 fail: 562 pass: 562
# 40138 fail: 700 pass: 700
# 40178 fail: 700 pass: 700
# 40179 fail: 655 pass: 655
# 40198 fail: 580 pass: 580
# 40303 fail: 684 pass: 684
# 40403 fail: 700 pass: 700
# problem_id: 3002
# 40117 fail: 700 pass: 700
# 40137 fail: 700 pass: 700
# 40151 fail: 700 pass: 700
# 40202 fail: 700 pass: 700
# 40215 fail: 700 pass: 700
# 40413 fail: 683 pass: 683
# 40415 fail: 700 pass: 700
# problem_id: 3008
# 40032 fail: 700 pass: 700
# 40042 fail: 700 pass: 700
# 40062 fail: 700 pass: 700
# 40166 fail: 700 pass: 700
# 40220 fail: 637 pass: 637
# 40229 fail: 700 pass: 700
# 40332 fail: 627 pass: 627
# 40343 fail: 626 pass: 626
# 40459 fail: 627 pass: 627
# problem_id: 3043
# 40048 fail: 535 pass: 535
# 40072 fail: 613 pass: 613
# 40095 fail: 700 pass: 700
# 40203 fail: 700 pass: 700
# 40206 fail: 656 pass: 656
# 40207 fail: 566 pass: 566
# 40209 fail: 647 pass: 647
# 40248 fail: 700 pass: 700
# 40293 fail: 691 pass: 691
# problem_id: 3016
# 40069 fail: 675 pass: 675
# 40175 fail: 700 pass: 700
# 40246 fail: 501 pass: 501
# 40265 fail: 541 pass: 541
# 40281 fail: 675 pass: 675
# 40313 fail: 700 pass: 700
# 40336 fail: 497 pass: 497
# 40356 fail: 700 pass: 700
# 40363 fail: 545 pass: 545
# 40424 fail: 700 pass: 700
# problem_id: 3037
# 40086 fail: 268 pass: 268
# 40097 fail: 294 pass: 294
# 40165 fail: 322 pass: 322
# 40225 fail: 338 pass: 338
# 40243 fail: 305 pass: 305
# 40361 fail: 316 pass: 316
# 40381 fail: 277 pass: 277
# 40411 fail: 299 pass: 299
# 40448 fail: 375 pass: 375
# problem_id: 3047
# 40018 fail: 575 pass: 575
# 40023 fail: 570 pass: 570
# 40038 fail: 583 pass: 583
# 40093 fail: 567 pass: 567
# 40269 fail: 686 pass: 686
# 40348 fail: 699 pass: 699
# 40451 fail: 700 pass: 700
# problem_id: 3007
# 40011 fail: 407 pass: 407
# 40083 fail: 589 pass: 589
# 40099 fail: 564 pass: 564
# 40107 fail: 401 pass: 401
# 40270 fail: 485 pass: 485
# problem_id: 3009
# 40064 fail: 554 pass: 554
# 40081 fail: 521 pass: 521
# 40087 fail: 528 pass: 528
# 40088 fail: 700 pass: 700
# 40131 fail: 573 pass: 573
# 40221 fail: 486 pass: 486
# 40329 fail: 487 pass: 487
# problem_id: 3049
# 40109 fail: 700 pass: 700
# 40133 fail: 700 pass: 700
# 40155 fail: 700 pass: 700
# 40189 fail: 700 pass: 700
# 40191 fail: 700 pass: 700
# 40239 fail: 700 pass: 700
# 40251 fail: 700 pass: 700
# 40314 fail: 700 pass: 700
# 40388 fail: 700 pass: 700
# problem_id: 3030
# 40025 fail: 573 pass: 573
# 40122 fail: 533 pass: 533
# 40226 fail: 504 pass: 504
# 40236 fail: 486 pass: 486
# 40340 fail: 695 pass: 695
# 40396 fail: 439 pass: 439
# 40398 fail: 485 pass: 485
# 40404 fail: 505 pass: 505
# 40416 fail: 476 pass: 476
# problem_id: 3055
# 40051 fail: 700 pass: 700
# 40112 fail: 700 pass: 700
# 40142 fail: 700 pass: 700
# 40157 fail: 700 pass: 700
# 40259 fail: 700 pass: 700
# 40261 fail: 700 pass: 700
# 40341 fail: 700 pass: 700
# 40389 fail: 700 pass: 700
# 40439 fail: 700 pass: 700
# problem_id: 3033
# 40008 fail: 700 pass: 700
# 40036 fail: 481 pass: 481
# 40094 fail: 489 pass: 489
# 40301 fail: 539 pass: 539
# 40315 fail: 505 pass: 505
# 40353 fail: 587 pass: 587
# 40367 fail: 555 pass: 555
# 40399 fail: 535 pass: 535
# problem_id: 3054
# 40128 fail: 646 pass: 646
# 40260 fail: 585 pass: 585
# 40272 fail: 700 pass: 700
# 40342 fail: 700 pass: 700
# 40360 fail: 700 pass: 700
# 40365 fail: 670 pass: 670
# 40402 fail: 638 pass: 638
# 40441 fail: 674 pass: 674
# problem_id: 3044
# 40120 fail: 334 pass: 334
# 40127 fail: 462 pass: 462
# 40180 fail: 471 pass: 471
# 40196 fail: 324 pass: 324
# 40318 fail: 467 pass: 467
# 40350 fail: 451 pass: 451
# 40364 fail: 322 pass: 322
# problem_id: 3050
# 40045 fail: 449 pass: 449
# 40173 fail: 691 pass: 691
# 40197 fail: 428 pass: 428
# 40217 fail: 474 pass: 474
# 40268 fail: 586 pass: 586
# 40275 fail: 492 pass: 492
# 40291 fail: 443 pass: 443
# problem_id: 3010
# 40017 fail: 485 pass: 485
# 40020 fail: 325 pass: 325
# 40046 fail: 342 pass: 342
# 40091 fail: 401 pass: 401
# 40111 fail: 395 pass: 395
# 40227 fail: 300 pass: 300
# 40238 fail: 327 pass: 327
# 40242 fail: 417 pass: 417
# 40289 fail: 426 pass: 426
# problem_id: 3025
# 40092 fail: 453 pass: 453
# 40110 fail: 568 pass: 568
# 40113 fail: 391 pass: 391
# 40144 fail: 461 pass: 461
# 40256 fail: 489 pass: 489
# 40358 fail: 449 pass: 449
# 40371 fail: 700 pass: 700
# problem_id: 3013
# 40074 fail: 587 pass: 587
# 40160 fail: 634 pass: 634
# 40230 fail: 636 pass: 636
# 40250 fail: 618 pass: 618
# 40276 fail: 695 pass: 695
# 40333 fail: 700 pass: 700
# 40418 fail: 700 pass: 700
# problem_id: 3036
# 40106 fail: 664 pass: 664
# 40194 fail: 642 pass: 642
# 40283 fail: 476 pass: 476
# 40327 fail: 496 pass: 496
# 40397 fail: 652 pass: 652
# 40456 fail: 700 pass: 700
# problem_id: 3017
# 40071 fail: 409 pass: 409
# 40171 fail: 392 pass: 392
# 40181 fail: 387 pass: 387
# 40185 fail: 553 pass: 553
# 40223 fail: 360 pass: 360
# 40298 fail: 462 pass: 462
# 40305 fail: 362 pass: 362
# 40306 fail: 433 pass: 433
# 40369 fail: 353 pass: 353
# 40390 fail: 381 pass: 381
# problem_id: 3048
# 40031 fail: 318 pass: 318
# 40039 fail: 435 pass: 435
# 40164 fail: 339 pass: 339
# 40290 fail: 403 pass: 403
# 40299 fail: 515 pass: 515
# 40310 fail: 351 pass: 351
# 40349 fail: 427 pass: 427
# 40442 fail: 341 pass: 341
# problem_id: 3029
# 40061 fail: 391 pass: 391
# 40177 fail: 391 pass: 391
# 40193 fail: 405 pass: 405
# 40211 fail: 699 pass: 699
# 40264 fail: 392 pass: 392
# 40295 fail: 403 pass: 403
# 40316 fail: 649 pass: 649
# 40326 fail: 395 pass: 395
# 40386 fail: 431 pass: 431
# 40408 fail: 650 pass: 650

# %%
new_all_data = {}
for problem_id in all_data:
    new_all_data[problem_id] = []
    for test_id in all_data[problem_id]:
        new_all_data[problem_id] += all_data[problem_id][test_id][0] + all_data[problem_id][test_id][1]
del all_data
all_data = new_all_data

total = 0
for problem_id in all_data:
    total += len(all_data[problem_id])

# %%
subtrees_per_program, nodes_per_subtree = [], []
max_subtrees_per_program, max_nodes_per_subtree = 0, 0
d = all_data.copy()
d.update(all_eval_data)
for problem_id, rows in d.items():
    for program_id, subtree_list_ast, test_id, verdict in rows:
        subtrees_per_program.append(len(subtree_list_ast))
        nodes_per_subtree.append(max([len(subtree) for subtree, coord in subtree_list_ast]))
        max_subtrees_per_program = max(max_subtrees_per_program, len(subtree_list_ast))
        max_nodes_per_subtree = max(max_nodes_per_subtree, *[len(subtree) for subtree, coord in subtree_list_ast])
        
print ('max_subtrees_per_program:', max_subtrees_per_program, 'max_nodes_per_subtree:', max_nodes_per_subtree)

assert len(subtrees_per_program) == len(nodes_per_subtree)

subtrees_per_program = list(sorted(subtrees_per_program))
nodes_per_subtree = list(sorted(nodes_per_subtree))

for percentile in [80,90,95,98,99]:
    i = int( percentile * len(nodes_per_subtree) / 100.0 )
    print ('percentile:', percentile, 'max_subtrees:',  subtrees_per_program[i], 'max_nodes:', nodes_per_subtree[i])
# Out:
# max_subtrees_per_program: 149 max_nodes_per_subtree: 21
# percentile: 80 max_subtrees: 78 max_nodes: 13
# percentile: 90 max_subtrees: 90 max_nodes: 15
# percentile: 95 max_subtrees: 110 max_nodes: 17
# percentile: 98 max_subtrees: 126 max_nodes: 18
# percentile: 99 max_subtrees: 133 max_nodes: 19

# %%
# Discard last percentile programs

max_trees = 149
max_nodes = 21
selected_data = {}
selected_eval_data = {}
for problem_id, rows in all_data.items():
    selected_data[problem_id] = []
    for program_id, subtree_list_ast, test_id, verdict in rows:
        if len(subtree_list_ast) <= max_trees and max([len(subtree) for subtree, coord in subtree_list_ast]) <= max_nodes:
            selected_data[problem_id].append((program_id, subtree_list_ast, test_id, verdict))

for problem_id, rows in all_eval_data.items():
    selected_eval_data[problem_id] = []
    for program_id, subtree_list_ast, test_id, verdict in rows:
        if len(subtree_list_ast) <= max_trees and max([len(subtree) for subtree, coord in subtree_list_ast]) <= max_nodes:
            selected_eval_data[problem_id].append((program_id, subtree_list_ast, test_id, verdict))

new_total = 0
for problem_id in selected_data:
    new_total += len(selected_data[problem_id])
print ('old-total', total, 'new_total:', new_total, 'difference:', total-new_total)

del all_data, all_eval_data
# Out:
# old-total 261174 new_total: 256297 difference: 4877

# %%
def get_id_map(ast, program_id=None):
    '''shuffles ids before assigning them indices using 
    program_id as randomness seed if program_id is not None'''
    
    ids = []
    for subtree, coord in ast:
        for node in subtree:
            if '_<id>_' in node and '@' in node:
                org_id = node.split('_<id>_')[1].split('@')[0]
                if org_id not in ids:
                    ids.append(org_id)
                    
    if program_id is not None:
        random.seed(program_id)
        random.shuffle(ids)

    id_map = {}
    for id_ in ids:
        id_map[id_] = len(id_map)
    return id_map

def normalize_ids(ast, id_map):
    new_ast = []
    for subtree, coord in ast:
        new_subtree = []
        for node in subtree:
            if '_<id>_' in node and '@' in node:
                org_id = node.split('_<id>_')[1].split('@')[0]
                new_subtree.append(node.replace('_<id>_' + org_id + '@', '_<id>_' + str(id_map[org_id]) + '@'))
            else:
                new_subtree.append(node)
        assert len(new_subtree) == len(subtree)
        new_ast.append((new_subtree, coord))
    return new_ast

normalized_data, normalized_eval_data = {}, {}

for problem_id in selected_data:
    normalized_data[problem_id] = []
    remaining = len(selected_data[problem_id]) - 1
    for program_id, subtree_list_ast, test_id, verdict in selected_data[problem_id]:
        if remaining % 250 == 0:
            print ('%s | remaining:%6d     \r' % (problem_id, remaining))
        remaining -= 1
        id_map = get_id_map(subtree_list_ast, program_id)
        norm_subtree_list_ast = normalize_ids(subtree_list_ast, id_map)
        normalized_data[problem_id] += [(program_id, id_map, norm_subtree_list_ast, test_id, verdict)]
    print()
del selected_data
        
for problem_id in selected_eval_data:
    normalized_eval_data[problem_id] = []
    for program_id, subtree_list_ast, test_id, verdict in selected_eval_data[problem_id]:
        id_map = get_id_map(subtree_list_ast, program_id)
        norm_subtree_list_ast = normalize_ids(subtree_list_ast, id_map)
        normalized_eval_data[problem_id] += [(program_id, id_map, norm_subtree_list_ast, test_id, verdict)]
        
del selected_eval_data
# Out:
# 3024 | remaining: 10500
# 3024 | remaining: 10250
# 3024 | remaining: 10000
# 3024 | remaining:  9750
# 3024 | remaining:  9500
# 3024 | remaining:  9250
# 3024 | remaining:  9000
# 3024 | remaining:  8750
# 3024 | remaining:  8500
# 3024 | remaining:  8250
# 3024 | remaining:  8000
# 3024 | remaining:  7750
# 3024 | remaining:  7500
# 3024 | remaining:  7250
# 3024 | remaining:  7000
# 3024 | remaining:  6750
# 3024 | remaining:  6500
# 3024 | remaining:  6250
# 3024 | remaining:  6000
# 3024 | remaining:  5750
# 3024 | remaining:  5500
# 3024 | remaining:  5250
# 3024 | remaining:  5000
# 3024 | remaining:  4750
# 3024 | remaining:  4500
# 3024 | remaining:  4250
# 3024 | remaining:  4000
# 3024 | remaining:  3750
# 3024 | remaining:  3500
# 3024 | remaining:  3250
# 3024 | remaining:  3000
# 3024 | remaining:  2750
# 3024 | remaining:  2500
# 3024 | remaining:  2250
# 3024 | remaining:  2000
# 3024 | remaining:  1750
# 3024 | remaining:  1500
# 3024 | remaining:  1250
# 3024 | remaining:  1000
# 3024 | remaining:   750
# 3024 | remaining:   500
# 3024 | remaining:   250
# 3024 | remaining:     0
#
# 3035 | remaining: 13250
# 3035 | remaining: 13000
# 3035 | remaining: 12750
# 3035 | remaining: 12500
# 3035 | remaining: 12250
# 3035 | remaining: 12000
# 3035 | remaining: 11750
# 3035 | remaining: 11500
# 3035 | remaining: 11250
# 3035 | remaining: 11000
# 3035 | remaining: 10750
# 3035 | remaining: 10500
# 3035 | remaining: 10250
# 3035 | remaining: 10000
# 3035 | remaining:  9750
# 3035 | remaining:  9500
# 3035 | remaining:  9250
# 3035 | remaining:  9000
# 3035 | remaining:  8750
# 3035 | remaining:  8500
# 3035 | remaining:  8250
# 3035 | remaining:  8000
# 3035 | remaining:  7750
# 3035 | remaining:  7500
# 3035 | remaining:  7250
# 3035 | remaining:  7000
# 3035 | remaining:  6750
# 3035 | remaining:  6500
# 3035 | remaining:  6250
# 3035 | remaining:  6000
# 3035 | remaining:  5750
# 3035 | remaining:  5500
# 3035 | remaining:  5250
# 3035 | remaining:  5000
# 3035 | remaining:  4750
# 3035 | remaining:  4500
# 3035 | remaining:  4250
# 3035 | remaining:  4000
# 3035 | remaining:  3750
# 3035 | remaining:  3500
# 3035 | remaining:  3250
# 3035 | remaining:  3000
# 3035 | remaining:  2750
# 3035 | remaining:  2500
# 3035 | remaining:  2250
# 3035 | remaining:  2000
# 3035 | remaining:  1750
# 3035 | remaining:  1500
# 3035 | remaining:  1250
# 3035 | remaining:  1000
# 3035 | remaining:   750
# 3035 | remaining:   500
# 3035 | remaining:   250
# 3035 | remaining:     0
#
# 3018 | remaining:  9500
# 3018 | remaining:  9250
# 3018 | remaining:  9000
# 3018 | remaining:  8750
# 3018 | remaining:  8500
# 3018 | remaining:  8250
# 3018 | remaining:  8000
# 3018 | remaining:  7750
# 3018 | remaining:  7500
# 3018 | remaining:  7250
# 3018 | remaining:  7000
# 3018 | remaining:  6750
# 3018 | remaining:  6500
# 3018 | remaining:  6250
# 3018 | remaining:  6000
# 3018 | remaining:  5750
# 3018 | remaining:  5500
# 3018 | remaining:  5250
# 3018 | remaining:  5000
# 3018 | remaining:  4750
# 3018 | remaining:  4500
# 3018 | remaining:  4250
# 3018 | remaining:  4000
# 3018 | remaining:  3750
# 3018 | remaining:  3500
# 3018 | remaining:  3250
# 3018 | remaining:  3000
# 3018 | remaining:  2750
# 3018 | remaining:  2500
# 3018 | remaining:  2250
# 3018 | remaining:  2000
# 3018 | remaining:  1750
# 3018 | remaining:  1500
# 3018 | remaining:  1250
# 3018 | remaining:  1000
# 3018 | remaining:   750
# 3018 | remaining:   500
# 3018 | remaining:   250
# 3018 | remaining:     0
#
# 3003 | remaining: 11000
# 3003 | remaining: 10750
# 3003 | remaining: 10500
# 3003 | remaining: 10250
# 3003 | remaining: 10000
# 3003 | remaining:  9750
# 3003 | remaining:  9500
# 3003 | remaining:  9250
# 3003 | remaining:  9000
# 3003 | remaining:  8750
# 3003 | remaining:  8500
# 3003 | remaining:  8250
# 3003 | remaining:  8000
# 3003 | remaining:  7750
# 3003 | remaining:  7500
# 3003 | remaining:  7250
# 3003 | remaining:  7000
# 3003 | remaining:  6750
# 3003 | remaining:  6500
# 3003 | remaining:  6250
# 3003 | remaining:  6000
# 3003 | remaining:  5750
# 3003 | remaining:  5500
# 3003 | remaining:  5250
# 3003 | remaining:  5000
# 3003 | remaining:  4750
# 3003 | remaining:  4500
# 3003 | remaining:  4250
# 3003 | remaining:  4000
# 3003 | remaining:  3750
# 3003 | remaining:  3500
# 3003 | remaining:  3250
# 3003 | remaining:  3000
# 3003 | remaining:  2750
# 3003 | remaining:  2500
# 3003 | remaining:  2250
# 3003 | remaining:  2000
# 3003 | remaining:  1750
# 3003 | remaining:  1500
# 3003 | remaining:  1250
# 3003 | remaining:  1000
# 3003 | remaining:   750
# 3003 | remaining:   500
# 3003 | remaining:   250
# 3003 | remaining:     0
#
# 3026 | remaining:  6500
# 3026 | remaining:  6250
# 3026 | remaining:  6000
# 3026 | remaining:  5750
# 3026 | remaining:  5500
# 3026 | remaining:  5250
# 3026 | remaining:  5000
# 3026 | remaining:  4750
# 3026 | remaining:  4500
# 3026 | remaining:  4250
# 3026 | remaining:  4000
# 3026 | remaining:  3750
# 3026 | remaining:  3500
# 3026 | remaining:  3250
# 3026 | remaining:  3000
# 3026 | remaining:  2750
# 3026 | remaining:  2500
# 3026 | remaining:  2250
# 3026 | remaining:  2000
# 3026 | remaining:  1750
# 3026 | remaining:  1500
# 3026 | remaining:  1250
# 3026 | remaining:  1000
# 3026 | remaining:   750
# 3026 | remaining:   500
# 3026 | remaining:   250
# 3026 | remaining:     0
#
# 3019 | remaining:  6000
# 3019 | remaining:  5750
# 3019 | remaining:  5500
# 3019 | remaining:  5250
# 3019 | remaining:  5000
# 3019 | remaining:  4750
# 3019 | remaining:  4500
# 3019 | remaining:  4250
# 3019 | remaining:  4000
# 3019 | remaining:  3750
# 3019 | remaining:  3500
# 3019 | remaining:  3250
# 3019 | remaining:  3000
# 3019 | remaining:  2750
# 3019 | remaining:  2500
# 3019 | remaining:  2250
# 3019 | remaining:  2000
# 3019 | remaining:  1750
# 3019 | remaining:  1500
# 3019 | remaining:  1250
# 3019 | remaining:  1000
# 3019 | remaining:   750
# 3019 | remaining:   500
# 3019 | remaining:   250
# 3019 | remaining:     0
#
# 3032 | remaining:  9000
# 3032 | remaining:  8750
# 3032 | remaining:  8500
# 3032 | remaining:  8250
# 3032 | remaining:  8000
# 3032 | remaining:  7750
# 3032 | remaining:  7500
# 3032 | remaining:  7250
# 3032 | remaining:  7000
# 3032 | remaining:  6750
# 3032 | remaining:  6500
# 3032 | remaining:  6250
# 3032 | remaining:  6000
# 3032 | remaining:  5750
# 3032 | remaining:  5500
# 3032 | remaining:  5250
# 3032 | remaining:  5000
# 3032 | remaining:  4750
# 3032 | remaining:  4500
# 3032 | remaining:  4250
# 3032 | remaining:  4000
# 3032 | remaining:  3750
# 3032 | remaining:  3500
# 3032 | remaining:  3250
# 3032 | remaining:  3000
# 3032 | remaining:  2750
# 3032 | remaining:  2500
# 3032 | remaining:  2250
# 3032 | remaining:  2000
# 3032 | remaining:  1750
# 3032 | remaining:  1500
# 3032 | remaining:  1250
# 3032 | remaining:  1000
# 3032 | remaining:   750
# 3032 | remaining:   500
# 3032 | remaining:   250
# 3032 | remaining:     0
#
# 3002 | remaining:  9750
# 3002 | remaining:  9500
# 3002 | remaining:  9250
# 3002 | remaining:  9000
# 3002 | remaining:  8750
# 3002 | remaining:  8500
# 3002 | remaining:  8250
# 3002 | remaining:  8000
# 3002 | remaining:  7750
# 3002 | remaining:  7500
# 3002 | remaining:  7250
# 3002 | remaining:  7000
# 3002 | remaining:  6750
# 3002 | remaining:  6500
# 3002 | remaining:  6250
# 3002 | remaining:  6000
# 3002 | remaining:  5750
# 3002 | remaining:  5500
# 3002 | remaining:  5250
# 3002 | remaining:  5000
# 3002 | remaining:  4750
# 3002 | remaining:  4500
# 3002 | remaining:  4250
# 3002 | remaining:  4000
# 3002 | remaining:  3750
# 3002 | remaining:  3500
# 3002 | remaining:  3250
# 3002 | remaining:  3000
# 3002 | remaining:  2750
# 3002 | remaining:  2500
# 3002 | remaining:  2250
# 3002 | remaining:  2000
# 3002 | remaining:  1750
# 3002 | remaining:  1500
# 3002 | remaining:  1250
# 3002 | remaining:  1000
# 3002 | remaining:   750
# 3002 | remaining:   500
# 3002 | remaining:   250
# 3002 | remaining:     0
#
# 3008 | remaining: 12000
# 3008 | remaining: 11750
# 3008 | remaining: 11500
# 3008 | remaining: 11250
# 3008 | remaining: 11000
# 3008 | remaining: 10750
# 3008 | remaining: 10500
# 3008 | remaining: 10250
# 3008 | remaining: 10000
# 3008 | remaining:  9750
# 3008 | remaining:  9500
# 3008 | remaining:  9250
# 3008 | remaining:  9000
# 3008 | remaining:  8750
# 3008 | remaining:  8500
# 3008 | remaining:  8250
# 3008 | remaining:  8000
# 3008 | remaining:  7750
# 3008 | remaining:  7500
# 3008 | remaining:  7250
# 3008 | remaining:  7000
# 3008 | remaining:  6750
# 3008 | remaining:  6500
# 3008 | remaining:  6250
# 3008 | remaining:  6000
# 3008 | remaining:  5750
# 3008 | remaining:  5500
# 3008 | remaining:  5250
# 3008 | remaining:  5000
# 3008 | remaining:  4750
# 3008 | remaining:  4500
# 3008 | remaining:  4250
# 3008 | remaining:  4000
# 3008 | remaining:  3750
# 3008 | remaining:  3500
# 3008 | remaining:  3250
# 3008 | remaining:  3000
# 3008 | remaining:  2750
# 3008 | remaining:  2500
# 3008 | remaining:  2250
# 3008 | remaining:  2000
# 3008 | remaining:  1750
# 3008 | remaining:  1500
# 3008 | remaining:  1250
# 3008 | remaining:  1000
# 3008 | remaining:   750
# 3008 | remaining:   500
# 3008 | remaining:   250
# 3008 | remaining:     0
#
# 3043 | remaining: 11500
# 3043 | remaining: 11250
# 3043 | remaining: 11000
# 3043 | remaining: 10750
# 3043 | remaining: 10500
# 3043 | remaining: 10250
# 3043 | remaining: 10000
# 3043 | remaining:  9750
# 3043 | remaining:  9500
# 3043 | remaining:  9250
# 3043 | remaining:  9000
# 3043 | remaining:  8750
# 3043 | remaining:  8500
# 3043 | remaining:  8250
# 3043 | remaining:  8000
# 3043 | remaining:  7750
# 3043 | remaining:  7500
# 3043 | remaining:  7250
# 3043 | remaining:  7000
# 3043 | remaining:  6750
# 3043 | remaining:  6500
# 3043 | remaining:  6250
# 3043 | remaining:  6000
# 3043 | remaining:  5750
# 3043 | remaining:  5500
# 3043 | remaining:  5250
# 3043 | remaining:  5000
# 3043 | remaining:  4750
# 3043 | remaining:  4500
# 3043 | remaining:  4250
# 3043 | remaining:  4000
# 3043 | remaining:  3750
# 3043 | remaining:  3500
# 3043 | remaining:  3250
# 3043 | remaining:  3000
# 3043 | remaining:  2750
# 3043 | remaining:  2500
# 3043 | remaining:  2250
# 3043 | remaining:  2000
# 3043 | remaining:  1750
# 3043 | remaining:  1500
# 3043 | remaining:  1250
# 3043 | remaining:  1000
# 3043 | remaining:   750
# 3043 | remaining:   500
# 3043 | remaining:   250
# 3043 | remaining:     0
#
# 3016 | remaining: 12250
# 3016 | remaining: 12000
# 3016 | remaining: 11750
# 3016 | remaining: 11500
# 3016 | remaining: 11250
# 3016 | remaining: 11000
# 3016 | remaining: 10750
# 3016 | remaining: 10500
# 3016 | remaining: 10250
# 3016 | remaining: 10000
# 3016 | remaining:  9750
# 3016 | remaining:  9500
# 3016 | remaining:  9250
# 3016 | remaining:  9000
# 3016 | remaining:  8750
# 3016 | remaining:  8500
# 3016 | remaining:  8250
# 3016 | remaining:  8000
# 3016 | remaining:  7750
# 3016 | remaining:  7500
# 3016 | remaining:  7250
# 3016 | remaining:  7000
# 3016 | remaining:  6750
# 3016 | remaining:  6500
# 3016 | remaining:  6250
# 3016 | remaining:  6000
# 3016 | remaining:  5750
# 3016 | remaining:  5500
# 3016 | remaining:  5250
# 3016 | remaining:  5000
# 3016 | remaining:  4750
# 3016 | remaining:  4500
# 3016 | remaining:  4250
# 3016 | remaining:  4000
# 3016 | remaining:  3750
# 3016 | remaining:  3500
# 3016 | remaining:  3250
# 3016 | remaining:  3000
# 3016 | remaining:  2750
# 3016 | remaining:  2500
# 3016 | remaining:  2250
# 3016 | remaining:  2000
# 3016 | remaining:  1750
# 3016 | remaining:  1500
# 3016 | remaining:  1250
# 3016 | remaining:  1000
# 3016 | remaining:   750
# 3016 | remaining:   500
# 3016 | remaining:   250
# 3016 | remaining:     0
#
# 3037 | remaining:  5500
# 3037 | remaining:  5250
# 3037 | remaining:  5000
# 3037 | remaining:  4750
# 3037 | remaining:  4500
# 3037 | remaining:  4250
# 3037 | remaining:  4000
# 3037 | remaining:  3750
# 3037 | remaining:  3500
# 3037 | remaining:  3250
# 3037 | remaining:  3000
# 3037 | remaining:  2750
# 3037 | remaining:  2500
# 3037 | remaining:  2250
# 3037 | remaining:  2000
# 3037 | remaining:  1750
# 3037 | remaining:  1500
# 3037 | remaining:  1250
# 3037 | remaining:  1000
# 3037 | remaining:   750
# 3037 | remaining:   500
# 3037 | remaining:   250
# 3037 | remaining:     0
#
# 3047 | remaining:  8250
# 3047 | remaining:  8000
# 3047 | remaining:  7750
# 3047 | remaining:  7500
# 3047 | remaining:  7250
# 3047 | remaining:  7000
# 3047 | remaining:  6750
# 3047 | remaining:  6500
# 3047 | remaining:  6250
# 3047 | remaining:  6000
# 3047 | remaining:  5750
# 3047 | remaining:  5500
# 3047 | remaining:  5250
# 3047 | remaining:  5000
# 3047 | remaining:  4750
# 3047 | remaining:  4500
# 3047 | remaining:  4250
# 3047 | remaining:  4000
# 3047 | remaining:  3750
# 3047 | remaining:  3500
# 3047 | remaining:  3250
# 3047 | remaining:  3000
# 3047 | remaining:  2750
# 3047 | remaining:  2500
# 3047 | remaining:  2250
# 3047 | remaining:  2000
# 3047 | remaining:  1750
# 3047 | remaining:  1500
# 3047 | remaining:  1250
# 3047 | remaining:  1000
# 3047 | remaining:   750
# 3047 | remaining:   500
# 3047 | remaining:   250
# 3047 | remaining:     0
#
# 3007 | remaining:  4750
# 3007 | remaining:  4500
# 3007 | remaining:  4250
# 3007 | remaining:  4000
# 3007 | remaining:  3750
# 3007 | remaining:  3500
# 3007 | remaining:  3250
# 3007 | remaining:  3000
# 3007 | remaining:  2750
# 3007 | remaining:  2500
# 3007 | remaining:  2250
# 3007 | remaining:  2000
# 3007 | remaining:  1750
# 3007 | remaining:  1500
# 3007 | remaining:  1250
# 3007 | remaining:  1000
# 3007 | remaining:   750
# 3007 | remaining:   500
# 3007 | remaining:   250
# 3007 | remaining:     0
#
# 3009 | remaining:  7500
# 3009 | remaining:  7250
# 3009 | remaining:  7000
# 3009 | remaining:  6750
# 3009 | remaining:  6500
# 3009 | remaining:  6250
# 3009 | remaining:  6000
# 3009 | remaining:  5750
# 3009 | remaining:  5500
# 3009 | remaining:  5250
# 3009 | remaining:  5000
# 3009 | remaining:  4750
# 3009 | remaining:  4500
# 3009 | remaining:  4250
# 3009 | remaining:  4000
# 3009 | remaining:  3750
# 3009 | remaining:  3500
# 3009 | remaining:  3250
# 3009 | remaining:  3000
# 3009 | remaining:  2750
# 3009 | remaining:  2500
# 3009 | remaining:  2250
# 3009 | remaining:  2000
# 3009 | remaining:  1750
# 3009 | remaining:  1500
# 3009 | remaining:  1250
# 3009 | remaining:  1000
# 3009 | remaining:   750
# 3009 | remaining:   500
# 3009 | remaining:   250
# 3009 | remaining:     0
#
# 3049 | remaining: 12500
# 3049 | remaining: 12250
# 3049 | remaining: 12000
# 3049 | remaining: 11750
# 3049 | remaining: 11500
# 3049 | remaining: 11250
# 3049 | remaining: 11000
# 3049 | remaining: 10750
# 3049 | remaining: 10500
# 3049 | remaining: 10250
# 3049 | remaining: 10000
# 3049 | remaining:  9750
# 3049 | remaining:  9500
# 3049 | remaining:  9250
# 3049 | remaining:  9000
# 3049 | remaining:  8750
# 3049 | remaining:  8500
# 3049 | remaining:  8250
# 3049 | remaining:  8000
# 3049 | remaining:  7750
# 3049 | remaining:  7500
# 3049 | remaining:  7250
# 3049 | remaining:  7000
# 3049 | remaining:  6750
# 3049 | remaining:  6500
# 3049 | remaining:  6250
# 3049 | remaining:  6000
# 3049 | remaining:  5750
# 3049 | remaining:  5500
# 3049 | remaining:  5250
# 3049 | remaining:  5000
# 3049 | remaining:  4750
# 3049 | remaining:  4500
# 3049 | remaining:  4250
# 3049 | remaining:  4000
# 3049 | remaining:  3750
# 3049 | remaining:  3500
# 3049 | remaining:  3250
# 3049 | remaining:  3000
# 3049 | remaining:  2750
# 3049 | remaining:  2500
# 3049 | remaining:  2250
# 3049 | remaining:  2000
# 3049 | remaining:  1750
# 3049 | remaining:  1500
# 3049 | remaining:  1250
# 3049 | remaining:  1000
# 3049 | remaining:   750
# 3049 | remaining:   500
# 3049 | remaining:   250
# 3049 | remaining:     0
#
# 3030 | remaining:  8750
# 3030 | remaining:  8500
# 3030 | remaining:  8250
# 3030 | remaining:  8000
# 3030 | remaining:  7750
# 3030 | remaining:  7500
# 3030 | remaining:  7250
# 3030 | remaining:  7000
# 3030 | remaining:  6750
# 3030 | remaining:  6500
# 3030 | remaining:  6250
# 3030 | remaining:  6000
# 3030 | remaining:  5750
# 3030 | remaining:  5500
# 3030 | remaining:  5250
# 3030 | remaining:  5000
# 3030 | remaining:  4750
# 3030 | remaining:  4500
# 3030 | remaining:  4250
# 3030 | remaining:  4000
# 3030 | remaining:  3750
# 3030 | remaining:  3500
# 3030 | remaining:  3250
# 3030 | remaining:  3000
# 3030 | remaining:  2750
# 3030 | remaining:  2500
# 3030 | remaining:  2250
# 3030 | remaining:  2000
# 3030 | remaining:  1750
# 3030 | remaining:  1500
# 3030 | remaining:  1250
# 3030 | remaining:  1000
# 3030 | remaining:   750
# 3030 | remaining:   500
# 3030 | remaining:   250
# 3030 | remaining:     0
#
# 3055 | remaining: 12500
# 3055 | remaining: 12250
# 3055 | remaining: 12000
# 3055 | remaining: 11750
# 3055 | remaining: 11500
# 3055 | remaining: 11250
# 3055 | remaining: 11000
# 3055 | remaining: 10750
# 3055 | remaining: 10500
# 3055 | remaining: 10250
# 3055 | remaining: 10000
# 3055 | remaining:  9750
# 3055 | remaining:  9500
# 3055 | remaining:  9250
# 3055 | remaining:  9000
# 3055 | remaining:  8750
# 3055 | remaining:  8500
# 3055 | remaining:  8250
# 3055 | remaining:  8000
# 3055 | remaining:  7750
# 3055 | remaining:  7500
# 3055 | remaining:  7250
# 3055 | remaining:  7000
# 3055 | remaining:  6750
# 3055 | remaining:  6500
# 3055 | remaining:  6250
# 3055 | remaining:  6000
# 3055 | remaining:  5750
# 3055 | remaining:  5500
# 3055 | remaining:  5250
# 3055 | remaining:  5000
# 3055 | remaining:  4750
# 3055 | remaining:  4500
# 3055 | remaining:  4250
# 3055 | remaining:  4000
# 3055 | remaining:  3750
# 3055 | remaining:  3500
# 3055 | remaining:  3250
# 3055 | remaining:  3000
# 3055 | remaining:  2750
# 3055 | remaining:  2500
# 3055 | remaining:  2250
# 3055 | remaining:  2000
# 3055 | remaining:  1750
# 3055 | remaining:  1500
# 3055 | remaining:  1250
# 3055 | remaining:  1000
# 3055 | remaining:   750
# 3055 | remaining:   500
# 3055 | remaining:   250
# 3055 | remaining:     0
#
# 3033 | remaining:  8750
# 3033 | remaining:  8500
# 3033 | remaining:  8250
# 3033 | remaining:  8000
# 3033 | remaining:  7750
# 3033 | remaining:  7500
# 3033 | remaining:  7250
# 3033 | remaining:  7000
# 3033 | remaining:  6750
# 3033 | remaining:  6500
# 3033 | remaining:  6250
# 3033 | remaining:  6000
# 3033 | remaining:  5750
# 3033 | remaining:  5500
# 3033 | remaining:  5250
# 3033 | remaining:  5000
# 3033 | remaining:  4750
# 3033 | remaining:  4500
# 3033 | remaining:  4250
# 3033 | remaining:  4000
# 3033 | remaining:  3750
# 3033 | remaining:  3500
# 3033 | remaining:  3250
# 3033 | remaining:  3000
# 3033 | remaining:  2750
# 3033 | remaining:  2500
# 3033 | remaining:  2250
# 3033 | remaining:  2000
# 3033 | remaining:  1750
# 3033 | remaining:  1500
# 3033 | remaining:  1250
# 3033 | remaining:  1000
# 3033 | remaining:   750
# 3033 | remaining:   500
# 3033 | remaining:   250
# 3033 | remaining:     0
#
# 3054 | remaining: 10500
# 3054 | remaining: 10250
# 3054 | remaining: 10000
# 3054 | remaining:  9750
# 3054 | remaining:  9500
# 3054 | remaining:  9250
# 3054 | remaining:  9000
# 3054 | remaining:  8750
# 3054 | remaining:  8500
# 3054 | remaining:  8250
# 3054 | remaining:  8000
# 3054 | remaining:  7750
# 3054 | remaining:  7500
# 3054 | remaining:  7250
# 3054 | remaining:  7000
# 3054 | remaining:  6750
# 3054 | remaining:  6500
# 3054 | remaining:  6250
# 3054 | remaining:  6000
# 3054 | remaining:  5750
# 3054 | remaining:  5500
# 3054 | remaining:  5250
# 3054 | remaining:  5000
# 3054 | remaining:  4750
# 3054 | remaining:  4500
# 3054 | remaining:  4250
# 3054 | remaining:  4000
# 3054 | remaining:  3750
# 3054 | remaining:  3500
# 3054 | remaining:  3250
# 3054 | remaining:  3000
# 3054 | remaining:  2750
# 3054 | remaining:  2500
# 3054 | remaining:  2250
# 3054 | remaining:  2000
# 3054 | remaining:  1750
# 3054 | remaining:  1500
# 3054 | remaining:  1250
# 3054 | remaining:  1000
# 3054 | remaining:   750
# 3054 | remaining:   500
# 3054 | remaining:   250
# 3054 | remaining:     0
#
# 3044 | remaining:  5500
# 3044 | remaining:  5250
# 3044 | remaining:  5000
# 3044 | remaining:  4750
# 3044 | remaining:  4500
# 3044 | remaining:  4250
# 3044 | remaining:  4000
# 3044 | remaining:  3750
# 3044 | remaining:  3500
# 3044 | remaining:  3250
# 3044 | remaining:  3000
# 3044 | remaining:  2750
# 3044 | remaining:  2500
# 3044 | remaining:  2250
# 3044 | remaining:  2000
# 3044 | remaining:  1750
# 3044 | remaining:  1500
# 3044 | remaining:  1250
# 3044 | remaining:  1000
# 3044 | remaining:   750
# 3044 | remaining:   500
# 3044 | remaining:   250
# 3044 | remaining:     0
#
# 3050 | remaining:  7000
# 3050 | remaining:  6750
# 3050 | remaining:  6500
# 3050 | remaining:  6250
# 3050 | remaining:  6000
# 3050 | remaining:  5750
# 3050 | remaining:  5500
# 3050 | remaining:  5250
# 3050 | remaining:  5000
# 3050 | remaining:  4750
# 3050 | remaining:  4500
# 3050 | remaining:  4250
# 3050 | remaining:  4000
# 3050 | remaining:  3750
# 3050 | remaining:  3500
# 3050 | remaining:  3250
# 3050 | remaining:  3000
# 3050 | remaining:  2750
# 3050 | remaining:  2500
# 3050 | remaining:  2250
# 3050 | remaining:  2000
# 3050 | remaining:  1750
# 3050 | remaining:  1500
# 3050 | remaining:  1250
# 3050 | remaining:  1000
# 3050 | remaining:   750
# 3050 | remaining:   500
# 3050 | remaining:   250
# 3050 | remaining:     0
#
# 3010 | remaining:  6500
# 3010 | remaining:  6250
# 3010 | remaining:  6000
# 3010 | remaining:  5750
# 3010 | remaining:  5500
# 3010 | remaining:  5250
# 3010 | remaining:  5000
# 3010 | remaining:  4750
# 3010 | remaining:  4500
# 3010 | remaining:  4250
# 3010 | remaining:  4000
# 3010 | remaining:  3750
# 3010 | remaining:  3500
# 3010 | remaining:  3250
# 3010 | remaining:  3000
# 3010 | remaining:  2750
# 3010 | remaining:  2500
# 3010 | remaining:  2250
# 3010 | remaining:  2000
# 3010 | remaining:  1750
# 3010 | remaining:  1500
# 3010 | remaining:  1250
# 3010 | remaining:  1000
# 3010 | remaining:   750
# 3010 | remaining:   500
# 3010 | remaining:   250
# 3010 | remaining:     0
#
# 3025 | remaining:  7000
# 3025 | remaining:  6750
# 3025 | remaining:  6500
# 3025 | remaining:  6250
# 3025 | remaining:  6000
# 3025 | remaining:  5750
# 3025 | remaining:  5500
# 3025 | remaining:  5250
# 3025 | remaining:  5000
# 3025 | remaining:  4750
# 3025 | remaining:  4500
# 3025 | remaining:  4250
# 3025 | remaining:  4000
# 3025 | remaining:  3750
# 3025 | remaining:  3500
# 3025 | remaining:  3250
# 3025 | remaining:  3000
# 3025 | remaining:  2750
# 3025 | remaining:  2500
# 3025 | remaining:  2250
# 3025 | remaining:  2000
# 3025 | remaining:  1750
# 3025 | remaining:  1500
# 3025 | remaining:  1250
# 3025 | remaining:  1000
# 3025 | remaining:   750
# 3025 | remaining:   500
# 3025 | remaining:   250
# 3025 | remaining:     0
#
# 3013 | remaining:  8750
# 3013 | remaining:  8500
# 3013 | remaining:  8250
# 3013 | remaining:  8000
# 3013 | remaining:  7750
# 3013 | remaining:  7500
# 3013 | remaining:  7250
# 3013 | remaining:  7000
# 3013 | remaining:  6750
# 3013 | remaining:  6500
# 3013 | remaining:  6250
# 3013 | remaining:  6000
# 3013 | remaining:  5750
# 3013 | remaining:  5500
# 3013 | remaining:  5250
# 3013 | remaining:  5000
# 3013 | remaining:  4750
# 3013 | remaining:  4500
# 3013 | remaining:  4250
# 3013 | remaining:  4000
# 3013 | remaining:  3750
# 3013 | remaining:  3500
# 3013 | remaining:  3250
# 3013 | remaining:  3000
# 3013 | remaining:  2750
# 3013 | remaining:  2500
# 3013 | remaining:  2250
# 3013 | remaining:  2000
# 3013 | remaining:  1750
# 3013 | remaining:  1500
# 3013 | remaining:  1250
# 3013 | remaining:  1000
# 3013 | remaining:   750
# 3013 | remaining:   500
# 3013 | remaining:   250
# 3013 | remaining:     0
#
# 3036 | remaining:  7250
# 3036 | remaining:  7000
# 3036 | remaining:  6750
# 3036 | remaining:  6500
# 3036 | remaining:  6250
# 3036 | remaining:  6000
# 3036 | remaining:  5750
# 3036 | remaining:  5500
# 3036 | remaining:  5250
# 3036 | remaining:  5000
# 3036 | remaining:  4750
# 3036 | remaining:  4500
# 3036 | remaining:  4250
# 3036 | remaining:  4000
# 3036 | remaining:  3750
# 3036 | remaining:  3500
# 3036 | remaining:  3250
# 3036 | remaining:  3000
# 3036 | remaining:  2750
# 3036 | remaining:  2500
# 3036 | remaining:  2250
# 3036 | remaining:  2000
# 3036 | remaining:  1750
# 3036 | remaining:  1500
# 3036 | remaining:  1250
# 3036 | remaining:  1000
# 3036 | remaining:   750
# 3036 | remaining:   500
# 3036 | remaining:   250
# 3036 | remaining:     0
#
# 3017 | remaining:  7250
# 3017 | remaining:  7000
# 3017 | remaining:  6750
# 3017 | remaining:  6500
# 3017 | remaining:  6250
# 3017 | remaining:  6000
# 3017 | remaining:  5750
# 3017 | remaining:  5500
# 3017 | remaining:  5250
# 3017 | remaining:  5000
# 3017 | remaining:  4750
# 3017 | remaining:  4500
# 3017 | remaining:  4250
# 3017 | remaining:  4000
# 3017 | remaining:  3750
# 3017 | remaining:  3500
# 3017 | remaining:  3250
# 3017 | remaining:  3000
# 3017 | remaining:  2750
# 3017 | remaining:  2500
# 3017 | remaining:  2250
# 3017 | remaining:  2000
# 3017 | remaining:  1750
# 3017 | remaining:  1500
# 3017 | remaining:  1250
# 3017 | remaining:  1000
# 3017 | remaining:   750
# 3017 | remaining:   500
# 3017 | remaining:   250
# 3017 | remaining:     0
#
# 3048 | remaining:  5500
# 3048 | remaining:  5250
# 3048 | remaining:  5000
# 3048 | remaining:  4750
# 3048 | remaining:  4500
# 3048 | remaining:  4250
# 3048 | remaining:  4000
# 3048 | remaining:  3750
# 3048 | remaining:  3500
# 3048 | remaining:  3250
# 3048 | remaining:  3000
# 3048 | remaining:  2750
# 3048 | remaining:  2500
# 3048 | remaining:  2250
# 3048 | remaining:  2000
# 3048 | remaining:  1750
# 3048 | remaining:  1500
# 3048 | remaining:  1250
# 3048 | remaining:  1000
# 3048 | remaining:   750
# 3048 | remaining:   500
# 3048 | remaining:   250
# 3048 | remaining:     0
#
# 3029 | remaining:  8500
# 3029 | remaining:  8250
# 3029 | remaining:  8000
# 3029 | remaining:  7750
# 3029 | remaining:  7500
# 3029 | remaining:  7250
# 3029 | remaining:  7000
# 3029 | remaining:  6750
# 3029 | remaining:  6500
# 3029 | remaining:  6250
# 3029 | remaining:  6000
# 3029 | remaining:  5750
# 3029 | remaining:  5500
# 3029 | remaining:  5250
# 3029 | remaining:  5000
# 3029 | remaining:  4750
# 3029 | remaining:  4500
# 3029 | remaining:  4250
# 3029 | remaining:  4000
# 3029 | remaining:  3750
# 3029 | remaining:  3500
# 3029 | remaining:  3250
# 3029 | remaining:  3000
# 3029 | remaining:  2750
# 3029 | remaining:  2500
# 3029 | remaining:  2250
# 3029 | remaining:  2000
# 3029 | remaining:  1750
# 3029 | remaining:  1500
# 3029 | remaining:  1250
# 3029 | remaining:  1000
# 3029 | remaining:   750
# 3029 | remaining:   500
# 3029 | remaining:   250
# 3029 | remaining:     0

# %% [markdown]
# ## Data partition

# %%
np.random.seed(1189)
vdp = 0.05
training_data, validation_data = {}, {}

for problem_id in normalized_data:
    total_size = len(normalized_data[problem_id])
    valid_data_size = int(vdp * total_size)
    np.random.shuffle(normalized_data[problem_id])
    validation_data[problem_id] = normalized_data[problem_id][:valid_data_size]
    training_data[problem_id] = normalized_data[problem_id][valid_data_size:]
    
test_data = normalized_eval_data
    
    
all_tests = set()
problem_id_dict = {}
program_ids_dict = {}
all_program_ids = set()
for problem_id in normalized_data:
    for program_id, id_map, norm_subtree_list_ast, test_id, verdict in (normalized_data[problem_id] + normalized_eval_data[problem_id]):
        assert problem_id == test_id_to_problem_id_map[test_id]
        all_tests.add(problem_id+test_id)
        all_program_ids.add(program_id)
        
test_dict = {}
for test_id in all_tests:
    test_dict[test_id] = len(test_dict)

print ('all tests:', len(test_dict))
print ('all programs:', len(all_program_ids))

all_problem_ids = sorted(normalized_data.keys())
for problem_id in all_problem_ids:
    if problem_id not in problem_id_dict:
        problem_id_dict[problem_id] = len(problem_id_dict)

print ('all problems:', len(problem_id_dict))

max_subtrees_per_program, max_nodes_per_subtree = 0, 0
for problem_id in normalized_data:
    for program_id, id_map, norm_subtree_list_ast, test_id, verdict in (normalized_data[problem_id] + normalized_eval_data[problem_id]):
        max_subtrees_per_program = max(max_subtrees_per_program, len(norm_subtree_list_ast))
        max_nodes_per_subtree = max(max_nodes_per_subtree, *[len(subtree) for subtree, coord in norm_subtree_list_ast])
        
info = {'max_subtrees_per_program':max_subtrees_per_program, 'max_nodes_per_subtree':max_nodes_per_subtree}
pprint (info)
# Out:
# all tests: 231
# all programs: 29993
# all problems: 29
# {'max_nodes_per_subtree': 21, 'max_subtrees_per_program': 149}

# %% [markdown]
# ## Generate and save subtree_list AST dataset

# %%
def build_dictionary_for_subtree_list_ast(data, tl_dict={}):

    def build_dict(subtree_list_ast, dict_ref):
        for subtree, coords in subtree_list_ast:
            for token in subtree:
                token = token.strip()
                if token not in dict_ref:
                    dict_ref[token] = len(dict_ref)

    tl_dict['_pad_'] = 0
    tl_dict['_eos_'] = 1

    for problem_id, rows in data.items():
        for _, _, subtree_list_ast, _, _ in rows:
            build_dict(subtree_list_ast, tl_dict)

    print ('dictionary size:', len(tl_dict))
    assert len(tl_dict) > 50
    return tl_dict

# %%
tl_dict = build_dictionary_for_subtree_list_ast(normalized_data)
tl_dict = build_dictionary_for_subtree_list_ast(normalized_eval_data, tl_dict)
rev_tl_dict = get_rev_dict(tl_dict)
# Out:
# dictionary size: 1146
# dictionary size: 1210

# %%
def save_dictionaries(destination, all_dicts):
    if type(all_dicts) == dict:
        all_dicts = (all_dicts, get_rev_dict(all_dicts))
    else:
        assert type(all_dicts) == tuple
    np.save(os.path.join(destination, 'all_dicts.npy'), all_dicts)

def load_dictionaries(destination):
    all_dicts = np.load(os.path.join(destination, 'all_dicts.npy')).item()
    assert type(all_dicts) == tuple, type(all_dicts)
    return all_dicts
    
def save_data(destination, fold_data, all_dicts):
    for key in fold_data.keys():
        print ('%s-data size:' % key, len(fold_data[key]))
        with open(os.path.join(destination, ('examples-%s.pkl' % key)), 'wb') as f:
            cp.dump(fold_data[key], f)
    save_dictionaries(destination, all_dicts)

# %% [markdown]
# ## Generate data with buggy subtrees for incorrect programs for which we could find corresponding correct programs with small diff

# %%
def get_buggy_lines(program_id):
    global eval_dict
    if program_id in eval_dict:
        return set(eval_dict[program_id][3])
    else:
        return set([0])

# %%
def vectorize_subtree_list_ast(_tl_dict, subtree_list_ast, buggy_lines):
    vec_ast = []
    buggy_subtrees = {line:set() for line in buggy_lines}
    found = 0
    for idx, (subtree, coord) in enumerate(subtree_list_ast):
        line, char = map(int, coord.split(':'))
        if line in buggy_lines: 
            buggy_subtrees[line].add(idx)
            found += 1
        
        vec_subtree = []
        for token in subtree:
            vec_subtree.append(_tl_dict[token])
        
        vec_ast.append(vec_subtree)

    if not (len(buggy_lines)==0 or found > 0):
        raise ValueError('buggy_lines:%d, found %d' % (len(buggy_lines), found))
    return vec_ast, buggy_subtrees

# %%
this_fold = {'train':[], 'test':[], 'validation':[], 'eval':[]}
total_processed, exceptions = 0, 0

erratic_ids = []
ast_vec_cache = {}
def vectorize(tl_dict, subtree_list_ast, program_id):
    if program_id not in ast_vec_cache:
        buggy_lines = get_buggy_lines(program_id)
        vec_ast, buggy_subtrees = vectorize_subtree_list_ast(tl_dict, subtree_list_ast, buggy_lines)
        ast_vec_cache[program_id] = (vec_ast, buggy_subtrees)        
    return ast_vec_cache[program_id]

for name, each in zip(['train', 'test', 'validation'], [training_data, test_data, validation_data]):
    for problem_id, rows in each.items():
        for program_id, id_map, norm_subtree_list_ast, test_id, verdict in rows:
            try:
                total_processed += 1
                vec_ast, buggy_subtrees = vectorize(tl_dict, norm_subtree_list_ast, program_id)
                assert problem_id == test_id_to_problem_id_map[test_id]
                this_fold[name] += [(problem_id_dict[problem_id], program_id, test_dict[problem_id+test_id], vec_ast, verdict, buggy_subtrees)]
                if program_id in eval_set_program_ids and not verdict:
                    this_fold['eval'] += [(problem_id_dict[problem_id], program_id, test_dict[problem_id+test_id], vec_ast, verdict, buggy_subtrees)]
            except Exception as e:
                erratic_ids.append(program_id)
                exceptions += 1

print ('\ntotal_processed:', total_processed, 'exceptions:', exceptions)
save_data(destination, this_fold, (tl_dict, test_dict, problem_id_dict, info, {}))
np.save(os.path.join(destination, 'errs_in_finding_buggy_subtrees.npy'), erratic_ids)
print ('saved at:', destination)
print (len(set(erratic_ids)), set(erratic_ids))
# Out:
# total_processed: 273617 exceptions: 0
# train-data size: 243495
# test-data size: 17320
# validation-data size: 12802
# eval-data size: 7558
# saved at: ../data/network_inputs/bugloc-17-09/
# 0 set()
